# %% [markdown]
# # read data

# %%
df = spark.table("project_cardio.bronze.cardio_csv")

# %%
df.display()

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("project_cardio.silver.cardio_csv")
